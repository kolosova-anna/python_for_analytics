# %% [markdown]
# ## 1 задача
# Скачать файл в уроке
#
# Считать данные с помощью pandas
#
# Вывести на экран первые 5 строк
#
# Посмотреть на описание признаков и на их содержание

# %%
import pandas as pd

# %%
df = pd.read_csv('kc-house-data.csv')
df
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %% [markdown]
# ## 2 задача
# Проведите первичный анализ данных
#
# Изучите типы данных
#
# Найдите количество пропущенных ячеек в данных
#
# Посчитайте основные статистики по всем признакам и поизучайте их
#
# Пишите выводы

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
df.dtypes
# Out:
# id                 int64
# date              object
# price            float64
# bedrooms           int64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object

# %%
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %% [markdown]
# _Выводы:_ По результатам df.info видно, что пропущенных ячеек в таблице нет. dtypes показала, что большинство типов данных в таблице int, несколько колонок с float-значениями и один столбик с типом данных object - это дата. df.describe позволила вывести основные статистики, такие как среднее, стандартное отклонение, минимальное и максимальное значения, а также  25-й, 50-й и 75-й квартили. Так, можно увидеть, что средняя цена квартиры 5.400881e+05 и в среднем дома имеют один или два этажа (1,49).

# %% [markdown]
# ## 3 задача
# ### 3.1 В каком диапазоне изменяются стоимости недвижимости?
# Стоимости недвижимости изменяются в диапазоне от 7.500000e+04 до 7.700000e+06

# %% [markdown]
# ### 3.2 Какую долю в среднем занимают жилая площадь от всей площади по всем домам?
# Для нахождения средней доли жилой площади от всей площади дома:
# ${2079.899736\over1.510697e+04} \approx 0.14$
#
# Жилая площадь занимает в среднем 14%.

# %% [markdown]
# ### 3.3 Как много домов с разными этажами в данных?

# %%
df[df['floors'] > 1]
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 6      1321400060  20140627T000000  257500.0         3       2.25
# 9      3793500160  20150312T000000  323000.0         3       2.50
# 12      114101516  20140528T000000  310000.0         3       1.00
# 14     1175000570  20150312T000000  530000.0         5       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 1             2570      7242     2.0           0     0  ...      7
# ...

# %% [markdown]
# В данных 10933 дома с несколькими этажами.

# %% [markdown]
# ### 3.4 Насколько хорошие состояния у домов в данных?
# Состояние домов оценивается по шкале от 0 до 5. Средний показатель равен 3,4. Большая часть домов имеет оценки 4 и 5. У большинства домов хорошее состояние.

# %% [markdown]
# ### 3.5 Найдите года, когда построили первый дом, когда построили последний дом в данных?
# Первый дом был построен в 1900-м году, посдледний - в 2015-м.

# %% [markdown]
# ## 4 задача
# ### 4.1 Сколько в среднем стоят дома, у которых 2 спальни?

# %%
df[df['floors'] == 2].describe()
# Out:
#                  id         price     bedrooms    bathrooms   sqft_living  \
# count  8.241000e+03  8.241000e+03  8241.000000  8241.000000   8241.000000
# mean   4.677829e+09  6.488912e+05     3.631234     2.622619   2571.279092
# std    2.915394e+09  4.339377e+05     0.848208     0.621065    954.709667
# min    1.000102e+06  9.000000e+04     0.000000     0.000000    550.000000
# 25%    2.180001e+09  3.788000e+05     3.000000     2.500000   1890.000000
# 50%    3.982700e+09  5.429500e+05     4.000000     2.500000   2440.000000
# 75%    7.518503e+09  7.725000e+05     4.000000     2.750000   3090.000000
# max    9.839301e+09  7.062500e+06    11.000000     7.750000  10040.000000
#
#            sqft_lot  floors   waterfront         view    condition  \
# count  8.241000e+03  8241.0  8241.000000  8241.000000  8241.000000
# mean   1.613374e+04     2.0     0.009101     0.248149     3.187841
# std    4.462930e+04     0.0     0.094969     0.794362     0.469613
# ...

# %% [markdown]
# Средняя стоимость дома с двумя спальнями = 6.488912e+05

# %% [markdown]
# ### 4.2 Какая в среднем общая площадь домов, у которых стоимость больше 600 000?

# %%
df[df['price'] > 6000000].describe()
# Out:
#                  id         price  bedrooms  bathrooms   sqft_living  \
# count  3.000000e+00  3.000000e+00  3.000000   3.000000      3.000000
# mean   8.593434e+09  7.215833e+06  5.666667   6.750000  10660.000000
# std    1.613577e+09  4.285902e+05  0.577350   1.952562   1206.109448
# min    6.762700e+09  6.885000e+06  5.000000   4.500000   9890.000000
# 25%    7.985800e+09  6.973750e+06  5.500000   6.125000   9965.000000
# 50%    9.208900e+09  7.062500e+06  6.000000   7.750000  10040.000000
# 75%    9.508800e+09  7.381250e+06  6.000000   7.875000  11045.000000
# max    9.808701e+09  7.700000e+06  6.000000   8.000000  12050.000000
#
#            sqft_lot    floors  waterfront  view  condition      grade  \
# count      3.000000  3.000000    3.000000   3.0   3.000000   3.000000
# mean   32099.666667  2.166667    0.333333   3.0   3.333333  12.333333
# std     4902.943028  0.288675    0.577350   1.0   0.577350   1.154701
# ...

# %% [markdown]
# Средняя общая площадь таких домов = 32099.666667

# %% [markdown]
# ### 4.3 Как много домов коснулся ремонт?

# %%
df[df['yr_renovated'] > 0].describe()
# Out:
#                  id         price    bedrooms   bathrooms   sqft_living  \
# count  9.140000e+02  9.140000e+02  914.000000  914.000000    914.000000
# mean   4.348365e+09  7.603790e+05    3.452954    2.298961   2320.693654
# std    2.893205e+09  6.077348e+05    1.040514    0.890498   1083.822532
# min    3.600057e+06  1.100000e+05    1.000000    0.750000    520.000000
# 25%    1.863253e+09  4.012500e+05    3.000000    1.750000   1554.750000
# 50%    3.699650e+09  6.000000e+05    3.000000    2.250000   2200.000000
# 75%    6.918700e+09  9.000000e+05    4.000000    2.750000   2877.500000
# max    9.829200e+09  7.700000e+06   11.000000    8.000000  12050.000000
#
#             sqft_lot      floors  waterfront        view   condition  \
# count     914.000000  914.000000  914.000000  914.000000  914.000000
# mean    16633.631291    1.510394    0.045952    0.613786    3.223195
# std     38024.835725    0.494937    0.209495    1.219891    0.519571
# ...

# %% [markdown]
# Ремонт коснулся 9.14000000 домов

# %% [markdown]
# ### 4.4 Насколько в среднем стоимость домов с оценкой grade домов выше 10 отличается от стоимости домов с оценкой grade меньше 4?

# %%
df[df['grade'] > 10].describe()
# Out:
#                  id         price    bedrooms   bathrooms   sqft_living  \
# count  5.020000e+02  5.020000e+02  502.000000  502.000000    502.000000
# mean   4.115276e+09  1.678635e+06    4.189243    3.628984   4668.340637
# std    2.756606e+09  9.197760e+05    0.846529    0.951373   1293.931170
# min    4.610050e+07  4.200000e+05    0.000000    0.000000   2370.000000
# 25%    1.853000e+09  1.075000e+06    4.000000    3.250000   3870.000000
# 50%    3.624275e+09  1.407500e+06    4.000000    3.500000   4400.000000
# 75%    6.725376e+09  1.950000e+06    5.000000    4.000000   5187.500000
# max    9.831200e+09  7.700000e+06    9.000000    8.000000  13540.000000
#
#             sqft_lot      floors  waterfront        view   condition  \
# count     502.000000  502.000000  502.000000  502.000000  502.000000
# mean    41004.627490    1.959163    0.061753    1.157371    3.197211
# std     92815.766519    0.391815    0.240946    1.495547    0.463166
# ...

# %%
df[df['grade'] < 4].describe()
# Out:
#                  id          price  bedrooms  bathrooms  sqft_living  \
# count  4.000000e+00       4.000000      4.00     4.0000     4.000000
# mean   3.880987e+09  189750.000000      0.75     0.1875   520.000000
# std    1.375205e+09   98001.275502      0.50     0.3750   165.126214
# min    2.420069e+09   75000.000000      0.00     0.0000   290.000000
# 25%    3.170827e+09  125250.000000      0.75     0.0000   462.500000
# 50%    3.700690e+09  202000.000000      1.00     0.0000   560.000000
# 75%    4.410850e+09  266500.000000      1.00     0.1875   617.500000
# max    5.702500e+09  280000.000000      1.00     0.7500   670.000000
#
#            sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# count      4.000000     4.0         4.0   4.0   4.000000    4.0    4.000000
# mean   25433.500000     1.0         0.0   0.0   2.750000    2.5  520.000000
# std    12892.936399     0.0         0.0   0.0   1.707825    1.0  165.126214
# ...

# %% [markdown]
# Стоимость этих домов отличается на: $1.678635e+06 - 189750.000000 = 1488885$

# %% [markdown]
# ## 5 задача
# ### 5.1 Выберите дом клиенту
# Клиент хочет дом с видом на набережную, как минимум с тремя ванными и с подвалом. Сколько вариантов есть у клиента?

# %%
df[(df['waterfront'] > 0) & (df['bathrooms'] >= 3) & (df['sqft_basement'] > 0)]
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 300    3225069065  20140624T000000  3075000.0         4       5.00
# 457    2122039094  20141126T000000   705000.0         3       3.00
# 1164   1247600105  20141020T000000  5110800.0         5       5.25
# 1261   7636800041  20140625T000000   995000.0         3       4.50
# 1315   7558700030  20150413T000000  5300000.0         6       6.00
# 1361   1925069082  20150511T000000  2200000.0         5       4.25
# 2626   7738500731  20140815T000000  4500000.0         5       5.50
# 2864   4114601570  20141118T000000  3600000.0         3       3.25
# 3914   9808700762  20140611T000000  7062500.0         5       4.50
# 3934   1269200229  20140723T000000  1379900.0         3       3.25
# 5760    623059016  20140717T000000  1100000.0         4       3.25
# 6233   2024069008  20140619T000000  2200000.0         5       4.75
# 6508   4217402115  20150421T000000  3650000.0         6       4.75
# ...

# %% [markdown]
# У клиента есть 41 вариант.

# %% [markdown]
# ### 5.2 Выберите дом клиенту
# Клиент хочет дом либо с очень красивым видом из окна, либо с видом на набережную, в очень хорошем состоянии и год постройки не меньше 1980 года. В какой ценовом диапазоне будут дома?

# %%
df[(df['view'] == 4) | ((df['waterfront'] > 0) & (df['condition'] == 5) & (df['yr_built'] >= 1980))].describe()
# Out:
#                  id         price    bedrooms   bathrooms   sqft_living  \
# count  3.190000e+02  3.190000e+02  319.000000  319.000000    319.000000
# mean   4.991007e+09  1.463711e+06    3.633229    2.793887   3351.473354
# std    2.931542e+09  9.522096e+05    1.107561    1.079593   1553.260668
# min    9.800107e+07  2.520000e+05    1.000000    0.750000    680.000000
# 25%    2.608125e+09  8.175000e+05    3.000000    2.250000   2425.000000
# 50%    4.114602e+09  1.185000e+06    4.000000    2.500000   3050.000000
# 75%    7.855100e+09  1.850000e+06    4.000000    3.250000   3911.000000
# max    9.829200e+09  6.885000e+06    7.000000    8.000000  13540.000000
#
#             sqft_lot      floors  waterfront   view   condition       grade  \
# count     319.000000  319.000000  319.000000  319.0  319.000000  319.000000
# mean    21594.987461    1.605016    0.423197    4.0    3.567398    9.078370
# std     35742.685384    0.580696    0.494842    0.0    0.744584    1.604868
# ...

# %% [markdown]
# Стоимость таких домов будет варьироваться в пределах от 2.52000000000 до 6.885000000000

# %% [markdown]
# ### 5.3 Выберите дом клиенту
# Клиент хочет дом без подвала, с двумя этажами, стоимостью до 150000. Какая оценка по состоянию у таких домов в среднем?

# %%
df[(df['sqft_basement'] == 0) & (df['floors'] == 2) & (df['price'] < 150000)].describe()
# Out:
#                  id          price  bedrooms  bathrooms  sqft_living  \
# count  6.000000e+00       6.000000  6.000000   6.000000     6.000000
# mean   6.508735e+09  128916.666667  2.666667   1.375000  1143.333333
# std    1.896467e+09   19489.527102  0.516398   0.306186   129.099445
# min    4.239400e+09   90000.000000  2.000000   1.000000   980.000000
# 25%    5.162553e+09  131000.000000  2.250000   1.125000  1035.000000
# 50%    6.432705e+09  136750.000000  3.000000   1.500000  1200.000000
# 75%    7.560350e+09  139875.000000  3.000000   1.500000  1222.500000
# max    9.272202e+09  140000.000000  3.000000   1.750000  1270.000000
#
#           sqft_lot  floors  waterfront  view  condition     grade  \
# count     6.000000     6.0         6.0   6.0   6.000000  6.000000
# mean   4507.333333     2.0         0.0   0.0   2.833333  7.000000
# std    3019.489471     0.0         0.0   0.0   0.983192  0.632456
# min    1561.000000     2.0         0.0   0.0   1.000000  6.000000
# ...

# %% [markdown]
# Средняя оценка по состоянию у таких домов = 2,83.
